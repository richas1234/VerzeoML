# %% [markdown]
# <h3>Pandas Dataframes</h3>

# %%
#Creating a pandas dataframe from list of lists
import pandas as pd
Df = pd.DataFrame(data = [
                        ['NJ', 'Towaco', 'Square'], 
                        ['CA', 'San Francisco', 'Oval'], 
                        ['TX', 'Austin', 'Triangle'],
                        ['MD', 'Baltimore', 'Square'], 
                        ['OH', 'Columbus', 'Hexagon'], 
                        ['IL', 'Chicago', 'Circle']],
             columns = ['State', 'City', 'Shape'])

# %%
Df
# Out:
#   State           City     Shape
# 0    NJ         Towaco    Square
# 1    CA  San Francisco      Oval
# 2    TX         Austin  Triangle
# 3    MD      Baltimore    Square
# 4    OH       Columbus   Hexagon
# 5    IL        Chicago    Circle

# %%
#Creating DataFrame from dict of narray/lists
import pandas as pd 
  
# intialise data of lists. 
data = {'Name':['Tom', 'nick', 'krish', 'jack'], 'Age':[20, 21, 19, 18]}
  
# Create DataFrame 
df = pd.DataFrame(data) 
df
# Out:
#     Name  Age
# 0    Tom   20
# 1   nick   21
# 2  krish   19
# 3   jack   18

# %%
#Creates a indexes DataFrame using arrays.
import pandas as pd 
  
# initialise data of lists. 
data = {'Name':['Tom', 'Jack', 'nick', 'juli'], 'marks':[99, 98, 95, 90]} 
  
# Creates pandas DataFrame. 
df = pd.DataFrame(data, index =['rank1', 'rank2', 'rank3', 'rank4'])
  
# print the data 
df
# Out:
#        Name  marks
# rank1   Tom     99
# rank2  Jack     98
# rank3  nick     95
# rank4  juli     90

# %%
l1=[1,2,3]
l2=[10,4,5]
list(zip(l1,l2))
# Out:
# [(1, 10), (2, 4), (3, 5)]

# %%
#Creating DataFrame using zip() function.
#Two lists can be merged by using list(zip()) function. Now, create the pandas DataFrame by calling pd.DataFrame() function.
import pandas as pd  
    
# List1  
Name = ['tom', 'krish', 'nick', 'juli']  
    
# List2  
Age = [25, 30, 26, 22]  
    
# get the list of tuples from two lists.  
# and merge them by using zip().  
list_of_tuples = list(zip(Name, Age))  
print(list_of_tuples)
    
# Assign data to tuples.  
list_of_tuples   
  
print(list_of_tuples)
# Converting lists of tuples into  
# pandas Dataframe.  
df = pd.DataFrame(list_of_tuples, columns = ['Name', 'Age'])  
     
# Print data.  
df
# Out:
# [('tom', 25), ('krish', 30), ('nick', 26), ('juli', 22)]
# [('tom', 25), ('krish', 30), ('nick', 26), ('juli', 22)]
#     Name  Age
# 0    tom   25
# 1  krish   30
# 2   nick   26
# 3   juli   22

# %%
#Creating DataFrame from Dicts of series.
import pandas as pd 
  
# Intialise data to Dicts of series. 
d = {'one' : pd.Series([10, 20, 30, 40], index =['a', 'b', 'c', 'd']), 
      'two' : pd.Series([10, 20, 30, 40], index =['a', 'b', 'c', 'd'])} 
  
# creates Dataframe. 
df = pd.DataFrame(d) 
  
# print the data. 
df
# Out:
#    one  two
# a   10   10
# b   20   20
# c   30   30
# d   40   40

# %%
#Load data from csv
import pandas as pd
df = pd.read_csv('RegularSeasonCompactResults.csv')

# %%
#Head,tail
df.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N    0.0
# 1    1985      25   1106      77   1354      70    H    0.0
# 2    1985      25   1112      63   1223      56    H    0.0
# 3    1985      25   1165      70   1432      54    H    0.0
# 4    1985      25   1192      86   1447      74    H    0.0

# %%
df.dtypes
# Out:
# Season      int64
# Daynum      int64
# Wteam       int64
# Wscore      int64
# Lteam       int64
# Lscore      int64
# Wloc       object
# Numot     float64
# dtype: object

# %%
df[['Wscore', 'Lscore']].head()
# Out:
#    Wscore  Lscore
# 0      81      64
# 1      77      70
# 2      63      56
# 3      70      54
# 4      86      74

# %%
#Shape of dataset
df.shape[1]
# Out:
# 8

# %%
#Columns in dataset
df.columns
# Out:
# Index(['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc',
#        'Numot'],
#       dtype='object')

# %%
#we can call the describe() function to see statistics like mean, min, etc about each column of the dataset.
df.describe()
# Out:
#              Season        Daynum         Wteam        Wscore         Lteam  \
# count  34640.000000  34640.000000  34640.000000  34640.000000  34640.000000
# mean    1988.949827     78.861836   1285.336952     79.221738   1283.643620
# std        2.507155     29.884548    104.115529     13.666648    105.719494
# min     1985.000000     11.000000   1102.000000     35.000000   1102.000000
# 25%     1987.000000     54.000000   1198.000000     70.000000   1190.000000
# 50%     1989.000000     81.000000   1281.000000     78.000000   1280.000000
# 75%     1991.000000    103.000000   1378.000000     87.000000   1378.000000
# max     1993.000000    132.000000   1464.000000    186.000000   1464.000000
#
#              Lscore         Numot
# count  34640.000000  34639.000000
# mean      67.256091      0.005427
# std       11.946812      0.086468
# min       25.000000      0.000000
# 25%       59.000000      0.000000
# 50%       67.000000      0.000000
# 75%       75.000000      0.000000
# max      150.000000      3.000000

# %%
#Max ,min,mean,median
df.max()
# Out:
# Season    1993.0
# Daynum     132.0
# Wteam     1464.0
# Wscore     186.0
# Lteam     1464.0
# Lscore     150.0
# Numot        3.0
# dtype: float64

# %%
df['Wscore'].max()
# Out:
# 186

# %%
df['Wscore'].argmax()#Let's say we want to actually see the game(row) where this max score happened.
#We can call the argmax() function to identify the row index
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
# 24970

# %%
df.iloc[[df['Wscore'].argmax()]]
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   """Entry point for launching an IPython kernel.
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 24970    1991      68   1258     186   1109     140    H    0.0

# %%
#Let's take this a step further. Let's say you want to know the game with the highest scoring winning team (this is what we just calculated), 
#but you then want to know how many points the losing team scored.
df.iloc[[df['Wscore'].argmax()]]['Lscore']
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning:
# The current behaviour of 'Series.argmax' is deprecated, use 'idxmax'
# instead.
# The behavior of 'argmax' will be corrected to return the positional
# maximum in the future. For now, use 'series.values.argmax' or
# 'np.argmax(np.array(values))' to get the position of the maximum
# row.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 24970    140
# Name: Lscore, dtype: int64

# %%
df[df['Wscore'] > 150]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 5269     1986      75   1258     151   1109     107    H    0.0
# 12046    1988      40   1328     152   1147      84    H    0.0
# 12355    1988      52   1328     151   1173      99    N    0.0
# 16040    1989      40   1328     152   1331     122    H    0.0
# 16853    1989      68   1258     162   1109     144    A    0.0
# 17867    1989      92   1258     181   1109     150    H    0.0
# 19653    1990      30   1328     173   1109     101    H    0.0
# 19971    1990      38   1258     152   1109     137    A    0.0
# 20022    1990      40   1116     166   1109     101    H    0.0
# 22145    1990      97   1258     157   1362     115    H    0.0
# 23582    1991      26   1318     152   1258     123    N    0.0
# 24341    1991      47   1328     172   1258     112    H    0.0
# 24970    1991      68   1258     186   1109     140    H    0.0
# 25656    1991      84   1106     151   1212      97    H    0.0
# 28687    1992      54   1261     159   1319      86    H    0.0

# %%
#Extracting only values
df.values
# Out:
# array([[1985, 20, 1228, ..., 64, 'N', 0.0],
#        [1985, 25, 1106, ..., 70, 'H', 0.0],
#        [1985, 25, 1112, ..., 56, 'H', 0.0],
#        ...,
#        [1993, 103, 1335, ..., 62, 'H', 0.0],
#        [1993, 103, 1338, ..., 79, 'A', 0.0],
#        [1993, 103, 1344, ..., 50, nan, nan]], dtype=object)

# %%
df.values[0][1]
# Out:
# 20

# %%
#Dataframe Iteration
df.isnull().sum()
# Out:
# Season    0
# Daynum    0
# Wteam     0
# Wscore    0
# Lteam     0
# Lscore    0
# Wloc      1
# Numot     1
# dtype: int64

# %%
#https://github.com/jonathanrocher/pandas_tutorial/blob/master/analyzing_and_manipulating_data_with_pandas_manual.pdf
#https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html

# %% [markdown]
# <h3>Append,concatenate and merge dataframes</h3>

# %% [markdown]
# <h3>Append a dataframe</h3>

# %%
#Creating an empty dataframe
dfObj = pd.DataFrame(columns=['User_ID', 'UserName', 'Action'])
 
print( dfObj, sep='\n')
# Out:
# Empty DataFrame
# Columns: [User_ID, UserName, Action]
# Index: []

# %%
dfObj
# Out:
# Empty DataFrame
# Columns: [User_ID, UserName, Action]
# Index: []

# %%
# Append  Dataframe by adding dictionaries
dfObj = dfObj.append({'User_ID': 23, 'UserName': 'Riti', 'Action': 'Login'}, ignore_index=True)
dfObj = dfObj.append({'User_ID': 24, 'UserName': 'Aadi', 'Action': 'Logout'}, ignore_index=True)
dfObj = dfObj.append({'User_ID': 25, 'UserName': 'Jack', 'Action': 'Login'}, ignore_index=True)
print("Dataframe Contens ", dfObj, sep='\n')
# Out:
# Dataframe Contens
#   User_ID UserName  Action
# 0      23     Riti   Login
# 1      24     Aadi  Logout
# 2      25     Jack   Login

# %%
#Create an complete empty DataFrame without any column name or indices
dfObj = pd.DataFrame()
print(dfObj)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Append columns to the Empty DataFrame
dfObj['UserName'] = ['Riti', 'Aadi', 'Jack']
dfObj['Name'] = ['Riti', 'Aadi', 'Jack']
#dfObj['Name'] = ['Riti', 'Aadi', 'Jack']
print("Dataframe Contents ", dfObj, sep='\n') #Automatically a range index is been formed
# Out:
# Dataframe Contents
#   UserName  Name
# 0     Riti  Riti
# 1     Aadi  Aadi
# 2     Jack  Jack

# %%
#Create an empty Dataframe with column names & row indices but no data
dfObj = pd.DataFrame(columns=['User_ID', 'UserName', 'Action'], index=['a', 'b', 'c'])
 
print("Empty Dataframe", dfObj, sep='\n')
# Out:
# Empty Dataframe
#   User_ID UserName Action
# a     NaN      NaN    NaN
# b     NaN      NaN    NaN
# c     NaN      NaN    NaN

# %%
#Appending the data directly to the indices
dfObj.loc['a'] = [23, 'Riti', 'Login']
dfObj.loc['b'] = [24, 'Aadi', 'Logout']
dfObj.loc['c'] = [25, 'Jack', 'Login']
print("Dataframe Contents ", dfObj, sep='\n')
# Out:
# Dataframe Contents
#   User_ID UserName  Action
# a      23     Riti   Login
# b      24     Aadi  Logout
# c      25     Jack   Login

# %%
#Appending rows with for loop
import pandas as pd
 
cols = ['Zip']
lst = []
zip = 32100
 
for a in range(10):
    lst.append([zip])
    zip = zip + 1
 
df = pd.DataFrame(lst, columns=cols)
 
print(df)
# Out:
#      Zip
# 0  32100
# 1  32101
# 2  32102
# 3  32103
# 4  32104
# 5  32105
# 6  32106
# 7  32107
# 8  32108
# 9  32109

# %% [markdown]
# <h3>Concatenate dataframe</h3>

# %%
#Concatenate two columns of dataframe in pandas python
import pandas as pd
import numpy as np
 
#Create a DataFrame
df1 = {
    'State':['Arizona','Georgia','Newyork','Indiana','Florida'],
    'State_code':['AZ','GG','NY','IN','SL'],
   'Score':[62,47,55,74,31]}
 
df1 = pd.DataFrame(df1,columns=['State','State_code','Score'])
print(df1)
# Out:
#      State State_code  Score
# 0  Arizona         AZ     62
# 1  Georgia         GG     47
# 2  Newyork         NY     55
# 3  Indiana         IN     74
# 4  Florida         SL     31

# %%
#Concatenate two string columns pandas:Let’s concatenate two columns of dataframe with ‘+’ as shown below
df1['state_and_code'] = df1['State'] + df1['State_code']
print(df1)
# Out:
#      State State_code  Score state_and_code
# 0  Arizona         AZ     62      ArizonaAZ
# 1  Georgia         GG     47      GeorgiaGG
# 2  Newyork         NY     55      NewyorkNY
# 3  Indiana         IN     74      IndianaIN
# 4  Florida         SL     31      FloridaSL

# %%
#Concatenate two string columns with space
df1['state_and_code'] = df1['State'] +' '+ df1['State_code']
print(df1)
# Out:
#      State State_code  Score state_and_code
# 0  Arizona         AZ     62     Arizona AZ
# 1  Georgia         GG     47     Georgia GG
# 2  Newyork         NY     55     Newyork NY
# 3  Indiana         IN     74     Indiana IN
# 4  Florida         SL     31     Florida SL

# %%
#Concatenate String and numeric column
df1['code_and_score'] = df1["State_code"]+ "-" + df1["Score"].map(str)
print(df1)
# Out:
#      State State_code  Score state_and_code code_and_score
# 0  Arizona         AZ     62     Arizona AZ          AZ-62
# 1  Georgia         GG     47     Georgia GG          GG-47
# 2  Newyork         NY     55     Newyork NY          NY-55
# 3  Indiana         IN     74     Indiana IN          IN-74
# 4  Florida         SL     31     Florida SL          SL-31

# %%
df2=df1.copy()

# %%
#Concating two dataframes
# Stack the DataFrames on top of each other, by default it is vertical concatenation
df3 = pd.concat([df1, df2], axis=0)

print(df3)
print('*' * 100)
# Place the DataFrames side by side
df4 = pd.concat([df1, df3.head(5)], axis=1)
print(df4)
# Out:
#      State State_code  Score state_and_code code_and_score
# 0  Arizona         AZ     62     Arizona AZ          AZ-62
# 1  Georgia         GG     47     Georgia GG          GG-47
# 2  Newyork         NY     55     Newyork NY          NY-55
# 3  Indiana         IN     74     Indiana IN          IN-74
# 4  Florida         SL     31     Florida SL          SL-31
# 0  Arizona         AZ     62     Arizona AZ          AZ-62
# 1  Georgia         GG     47     Georgia GG          GG-47
# 2  Newyork         NY     55     Newyork NY          NY-55
# 3  Indiana         IN     74     Indiana IN          IN-74
# 4  Florida         SL     31     Florida SL          SL-31
# ****************************************************************************************************
#      State State_code  Score state_and_code code_and_score    State  \
# 0  Arizona         AZ     62     Arizona AZ          AZ-62  Arizona
# 1  Georgia         GG     47     Georgia GG          GG-47  Georgia
# 2  Newyork         NY     55     Newyork NY          NY-55  Newyork
# 3  Indiana         IN     74     Indiana IN          IN-74  Indiana
# 4  Florida         SL     31     Florida SL          SL-31  Florida
#
#   State_code  Score state_and_code code_and_score
# 0         AZ     62     Arizona AZ          AZ-62
# 1         GG     47     Georgia GG          GG-47
# 2         NY     55     Newyork NY          NY-55
# 3         IN     74     Indiana IN          IN-74
# 4         SL     31     Florida SL          SL-31

# %%
#Concatenating with index resetting
df3 = pd.concat([df1, df2], axis=0,ignore_index=True)

print(df3)
# Out:
#      State State_code  Score state_and_code code_and_score
# 0  Arizona         AZ     62     Arizona AZ          AZ-62
# 1  Georgia         GG     47     Georgia GG          GG-47
# 2  Newyork         NY     55     Newyork NY          NY-55
# 3  Indiana         IN     74     Indiana IN          IN-74
# 4  Florida         SL     31     Florida SL          SL-31
# 5  Arizona         AZ     62     Arizona AZ          AZ-62
# 6  Georgia         GG     47     Georgia GG          GG-47
# 7  Newyork         NY     55     Newyork NY          NY-55
# 8  Indiana         IN     74     Indiana IN          IN-74
# 9  Florida         SL     31     Florida SL          SL-31

# %%
#Concatenating pandas dataframes using .append()
dataflair_A = pd.DataFrame([['a', 1], ['b', 2]], columns=['letter', 'number'])
dataflair_B = pd.DataFrame([['c', 3], ['d', 4]], columns=['letter', 'number'])
result = dataflair_A.append(dataflair_B)

# %%
result
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %%
print('dataflair_A ->')
print(dataflair_A)
print('dataflair_B ->')
print(dataflair_B)
print('Result ->')
print(result)
# Out:
# dataflair_A ->
#   letter  number
# 0      a       1
# 1      b       2
# dataflair_B ->
#   letter  number
# 0      c       3
# 1      d       4
# Result ->
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       3
# 1      d       4

# %% [markdown]
# <h3>Merge dataframes</h3>

# %% [markdown]
# #Why “Merge”?
#
# You’d have probably encountered multiple data tables that have various bits of information that you would like to see all in one place — one dataframe in this case.
# And this is where the power of merge comes in to efficiently combine multiple data tables together in a nice and orderly fashion into a single dataframe for further analysis.

# %% [markdown]
# “Merging” two datasets is the process of bringing two datasets together into one, and aligning the rows from each based on common attributes or columns.

# %% [markdown]
# The words “merge” and “join” are used relatively interchangeably in Pandas and other languages. Despite the fact that Pandas has both “merge” and “join” functions, essentially they both do the similar things.

# %% [markdown]
# ![1_RQnYfkGBTsA28WDdkudzvw.png](attachment:1_RQnYfkGBTsA28WDdkudzvw.png)

# %% [markdown]
# To understand pd.merge, let’s start with a simple line of code as below. What this line of code does is to merge two dataframes — left_dfand right_df — into one based on their values with the samecolumn_name available in both dataframes. With the how='inner', this will perform inner merge to only combine values in the column_name that match.
# pd.merge(left_df, right_df, on='column_name', how='inner'
# Since the method how has different parameters (by default Pandas uses inner), we’ll look into different parameters (left, right, inner, outer) and their use cases.

# %% [markdown]
# Quick loot at data:
#
# user_usage — A first dataset containing users monthly mobile usage statistics.
#
# user_device — A second dataset containing details of an individual “use” of the system, with dates and device information.
#
# android_device — A third dataset with device and manufacturer data, which lists all Android devices and their model code

# %%
import pandas as pd

# %%
user_usage = pd.read_csv(r"D:\Data_Science\Batch1_Lessons\user_usage.csv")
user_device = pd.read_csv(r"D:\Data_Science\Batch1_Lessons\user_device.csv")
android_device = pd.read_csv(r"D:\Data_Science\Batch1_Lessons\android_devices.csv")

# %%
user_usage.head(5)
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792

# %%
user_device.shape
# Out:
# (272, 6)

# %%
user_device.head(5)
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3
# 2   22784    28473  android               5.1   SM-G903F            1
# 3   22785    15200      ios              10.2  iPhone7,2            3
# 4   22786    28239  android               6.0  ONE E1003            1

# %%
# INNER Merge
#Pandas uses “inner” merge by default. This keeps only the common values in both the left and right dataframes for the merged data.
#In our case, only the rows that contain use_id values that are common between user_usage and user_device remain in the merged data — inner_merge.
inner_merge = pd.merge(user_usage,user_device, on='use_id',how='inner')
inner_merge.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0    12921  android               4.3  GT-I9505            1
# 1    28714  android               6.0  SM-G930F            1
# 2    28714  android               6.0  SM-G930F            1
# 3    29592  android               5.1     D2303            1
# 4    28217  android               5.1  SM-G361F            1

# %%
inner_merge.shape
# Out:
# (159, 9)

# %%
android_device.head(5)
# Out:
#   Retail Branding Marketing Name    Device                      Model
# 0             NaN            NaN    AD681H  Smartfren Andromax AD681H
# 1             NaN            NaN     FJL21                      FJL21
# 2             NaN            NaN       T31              Panasonic T31
# 3             NaN            NaN  hws7721g         MediaPad 7 Youth 2
# 4              3Q        OC1020A   OC1020A                    OC1020A

# %% [markdown]
# It’s important to note here that:
#
# The column name use_id is shared between the user_usage and user_device.
#
# The device column of user_device and Model column of the android_device dataframe contain common codes

# %% [markdown]
# ![join-types-merge-names.jpg](attachment:join-types-merge-names.jpg)

# %%
#LEFT Merge
#Keep every row in the left dataframe. 
#Where there are missing values of the “on” variable in the right dataframe, add empty / NaN values in the result.
left_merge = pd.merge(user_device,user_usage, on='use_id',how='left')
left_merge
# Out:
#      use_id  user_id platform  platform_version                  device  \
# 0     22782    26980      ios              10.2               iPhone7,2
# 1     22783    29628  android               6.0                 Nexus 5
# 2     22784    28473  android               5.1                SM-G903F
# 3     22785    15200      ios              10.2               iPhone7,2
# 4     22786    28239  android               6.0               ONE E1003
# 5     22787    12921  android               4.3                GT-I9505
# 6     22788    28714  android               6.0                SM-G930F
# 7     22789    28714  android               6.0                SM-G930F
# 8     22790    29592  android               5.1                   D2303
# 9     22791    28775      ios              10.2               iPhone6,2
# 10    22792    28217  android               5.1                SM-G361F
# 11    22793    28217  android               5.1                SM-G361F
# 12    22794    28217  android               5.1                SM-G361F
# 13    22795    28217  android               5.1                SM-G361F
# 14    22796    29641      ios              10.2               iPhone7,2
# 15    22797    29642      ios              10.1               iPhone5,2
# 16    22798    29642      ios              10.1               iPhone5,2
# 17    22799    29643  android               6.0           ONEPLUS A3003
# 18    22800    14785  android               4.4               SM-A300FU
# 19    22801    10976  android               4.4                GT-I9505
# 20    22802    10976  android               4.4                GT-I9505
# 21    22803    29644  android               5.1               ONE E1003
# 22    22804    29645  android               6.0                SM-G935F
# 23    22805    29646  android               4.2                GT-I9195
# 24    22806    21615  android               6.0                   A0001
# 25    22807    29647  android               6.0           ONEPLUS A3003
# 26    22808    29065  android               6.0                SM-G900F
# 27    22809    29648      ios              10.2               iPhone7,2
# 28    22810    29649      ios              10.2               iPhone8,1
# 29    22811    29650      ios               9.3                 iPad3,1
# ..      ...      ...      ...               ...                     ...
# 242   23024    28637  android               6.0          MotoE2(4G-LTE)
# 243   23025    29715      ios              10.1               iPhone6,2
# 244   23026    22763  android               6.0               ONE A2003
# 245   23027    18108  android               4.4                     X11
# 246   23028    29716  android               5.1                   C6603
# 247   23029    29717  android               6.0              HTC One_M8
# 248   23030    27979  android               5.1               SM-J320FN
# 249   23031    27979  android               5.1               SM-J320FN
# 250   23032    27979  android               5.1               SM-J320FN
# 251   23033    28316      ios              10.2               iPhone7,1
# 252   23034    27979  android               5.1               SM-J320FN
# 253   23035    29718      ios              10.2               iPhone7,2
# 254   23036    29719  android               5.1                  VF-795
# 255   23037    29720      ios              10.2               iPhone7,1
# 256   23038    29720      ios              10.2               iPhone7,1
# 257   23039    29721  android               5.1                SM-G531F
# 258   23040    29723  android               4.4          HTC Desire 620
# 259   23041    28953  android               6.0                SM-G900F
# 260   23042    28953  android               6.0                SM-G900F
# 261   23043    28953  android               6.0                SM-G900F
# 262   23044    28953  android               6.0                SM-G900F
# 263   23045    29720      ios              10.2               iPhone7,1
# 264   23046    29454  android               6.0              Moto G (4)
# 265   23047    29720      ios              10.2               iPhone7,1
# 266   23048    29724  android               6.0           ONEPLUS A3003
# 267   23049    29725  android               6.0                SM-G900F
# 268   23050    29726      ios              10.2               iPhone7,2
# 269   23051    29726      ios              10.2               iPhone7,2
# 270   23052    29727      ios              10.1               iPhone8,4
# 271   23053    20257  android               5.1  Vodafone Smart ultra 6
#
#      use_type_id  outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb
# 0              2                      NaN                     NaN         NaN
# 1              3                      NaN                     NaN         NaN
# 2              1                      NaN                     NaN         NaN
# 3              3                      NaN                     NaN         NaN
# 4              1                      NaN                     NaN         NaN
# 5              1                    21.97                    4.82     1557.33
# 6              1                  1710.08                  136.88     7267.55
# 7              1                  1710.08                  136.88     7267.55
# 8              1                    94.46                   35.17      519.12
# 9              3                      NaN                     NaN         NaN
# 10             1                    71.59                   79.26     1557.33
# 11             1                    71.59                   79.26     1557.33
# 12             1                    71.59                   79.26      519.12
# 13             1                    71.59                   79.26      519.12
# 14             3                      NaN                     NaN         NaN
# 15             3                      NaN                     NaN         NaN
# 16             3                      NaN                     NaN         NaN
# 17             1                    30.92                   22.77     3114.67
# 18             1                      NaN                     NaN         NaN
# 19             1                    69.80                   14.70    25955.55
# 20             3                      NaN                     NaN         NaN
# 21             3                      NaN                     NaN         NaN
# 22             1                   554.41                  150.06     3114.67
# 23             1                   189.10                   24.08      519.12
# 24             1                   283.30                  107.47    15573.33
# 25             1                      NaN                     NaN         NaN
# 26             1                   324.34                   92.52      519.12
# 27             3                      NaN                     NaN         NaN
# 28             3                      NaN                     NaN         NaN
# 29             3                      NaN                     NaN         NaN
# ..           ...                      ...                     ...         ...
# 242            1                    70.34                   18.00      212.64
# 243            3                      NaN                     NaN         NaN
# 244            1                   532.98                   44.36     2076.45
# 245            1                    60.08                  261.33    12458.67
# 246            1                    92.52                  162.39     1557.33
# 247            1                    22.85                   34.54     6577.12
# 248            1                   227.13                   76.94        0.00
# 249            1                   227.13                   76.94     1038.21
# 250            1                   227.13                   76.94     1038.21
# 251            2                      NaN                     NaN         NaN
# 252            3                      NaN                     NaN         NaN
# 253            3                      NaN                     NaN         NaN
# 254            1                    57.66                   62.85     1557.33
# 255            3                      NaN                     NaN         NaN
# 256            2                      NaN                     NaN         NaN
# 257            1                   180.18                   17.49     2076.45
# 258            1                    12.85                   58.32       74.40
# 259            1                   198.59                   90.49     5191.12
# 260            3                      NaN                     NaN         NaN
# 261            1                   198.59                   90.49     5191.12
# 262            1                   198.59                   90.49     3114.67
# 263            2                      NaN                     NaN         NaN
# 264            1                   106.65                   82.13     5191.12
# 265            2                      NaN                     NaN         NaN
# 266            3                      NaN                     NaN         NaN
# 267            1                   344.53                   20.53      519.12
# 268            3                      NaN                     NaN         NaN
# 269            3                      NaN                     NaN         NaN
# 270            3                      NaN                     NaN         NaN
# 271            1                    42.75                   46.83     5191.12
#
# [272 rows x 9 columns]

# %%
user_usage.shape
# Out:
# (240, 4)

# %%
user_device.shape
# Out:
# (272, 6)

# %%
left_merge.tail()
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 235                   260.66                   68.44      896.96   25008
# 236                    97.12                   36.50     2815.00   25040
# 237                   355.93                   12.37     6828.09   25046
# 238                   632.06                  120.46     1453.16   25058
# 239                   488.70                  906.92     3089.85   25220
#
#      user_id platform  platform_version device  use_type_id
# 235      NaN      NaN               NaN    NaN          NaN
# 236      NaN      NaN               NaN    NaN          NaN
# 237      NaN      NaN               NaN    NaN          NaN
# 238      NaN      NaN               NaN    NaN          NaN
# 239      NaN      NaN               NaN    NaN          NaN

# %% [markdown]
# As expected, the column use_id has already been merged together. We also see that the empty values are replaced by NaN in the right dataframe — user_device.

# %%
#RIGHT Merge
#To perform the right merge, we just repeat the code above by simply changing the parameter of how from left to right.
right_merge = pd.merge(user_usage,user_device, on='use_id',how='right')
right_merge.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0    12921  android               4.3  GT-I9505            1
# 1    28714  android               6.0  SM-G930F            1
# 2    28714  android               6.0  SM-G930F            1
# 3    29592  android               5.1     D2303            1
# 4    28217  android               5.1  SM-G361F            1

# %%
right_merge.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0    12921  android               4.3  GT-I9505            1
# 1    28714  android               6.0  SM-G930F            1
# 2    28714  android               6.0  SM-G930F            1
# 3    29592  android               5.1     D2303            1
# 4    28217  android               5.1  SM-G361F            1

# %% [markdown]
# This time, we see that the empty values are replaced by NaN in the left dataframe — user_usage.

# %%
inner_merge.tail()
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 154                   198.59                   90.49     5191.12   23043
# 155                   198.59                   90.49     3114.67   23044
# 156                   106.65                   82.13     5191.12   23046
# 157                   344.53                   20.53      519.12   23049
# 158                    42.75                   46.83     5191.12   23053
#
#      user_id platform  platform_version                  device  use_type_id
# 154    28953  android               6.0                SM-G900F            1
# 155    28953  android               6.0                SM-G900F            1
# 156    29454  android               6.0              Moto G (4)            1
# 157    29725  android               6.0                SM-G900F            1
# 158    20257  android               5.1  Vodafone Smart ultra 6            1

# %% [markdown]
# Although the “inner” merge is used by Pandas by default, the parameter inner is specified above to be explicit.
#
# With the operation above, the merged data — inner_merge has different size compared to the original left and right dataframes (user_usage & user_device) as only common values are merged.

# %%
#Finally, we have “outer” merge.
#The “outer” merge combines all the rows for left and right dataframes with NaN when there are no matched values in the rows.
outer_merge = pd.merge(user_usage,user_device, on='use_id',how='outer',indicator=True)
outer_merge.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id _merge
# 0  12921.0  android               4.3  GT-I9505          1.0   both
# 1  28714.0  android               6.0  SM-G930F          1.0   both
# 2  28714.0  android               6.0  SM-G930F          1.0   both
# 3  29592.0  android               5.1     D2303          1.0   both
# 4  28217.0  android               5.1  SM-G361F          1.0   both

# %%
outer_merge.iloc[[0,1,200,201,350,351]]
# Out:
#      outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                      21.97                    4.82     1557.33   22787
# 1                    1710.08                  136.88     7267.55   22788
# 200                    28.79                   29.42     3114.67   23988
# 201                   616.56                   99.85     5414.14   24006
# 350                      NaN                     NaN         NaN   23050
# 351                      NaN                     NaN         NaN   23051
#
#      user_id platform  platform_version     device  use_type_id      _merge
# 0    12921.0  android               4.3   GT-I9505          1.0        both
# 1    28714.0  android               6.0   SM-G930F          1.0        both
# 200      NaN      NaN               NaN        NaN          NaN   left_only
# 201      NaN      NaN               NaN        NaN          NaN   left_only
# 350  29726.0      ios              10.2  iPhone7,2          3.0  right_only
# 351  29726.0      ios              10.2  iPhone7,2          3.0  right_only

# %% [markdown]
# To further illustrate how the “outer” merge works, we purposely specify certain rows of the outer_merge to understand where the rows originate from.
#
# For the 1st and 2th rows, the rows come from both the dataframes as they have the same values of use_id to be merged.
#
# For the 3rd and 4th rows, the rows come from the left dataframe as the right dataframe doesn’t have the common values of use_id.
#
# For the 5th and 6th rows, the rows come from the right dataframe as the left dataframe doesn’t have the common values of use_id.

# %%
#Merge Dataframes with Different Column Names
#So we’ve talked about how to merge data using different ways — left, right, inner, and outer.
#But the method on only works for the same column name in the left and right dataframes.
#Therefore, we use left_on and right_on to replace the method on as shown below.
left_merge = pd.merge(user_device,android_device, left_on='device',right_on='Model',how='left',indicator=True)
left_merge.head()

#Here we’ve merged user_device with android_device since they both contain common codes in their columns — device and Model respectively.
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id  \
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3
# 2   22784    28473  android               5.1   SM-G903F            1
# 3   22785    15200      ios              10.2  iPhone7,2            3
# 4   22786    28239  android               6.0  ONE E1003            1
#
#   Retail Branding Marketing Name      Device      Model     _merge
# 0             NaN            NaN         NaN        NaN  left_only
# 1             LGE        Nexus 5  hammerhead    Nexus 5       both
# 2         Samsung  Galaxy S5 Neo    s5neolte   SM-G903F       both
# 3             NaN            NaN         NaN        NaN  left_only
# 4         OnePlus        OnePlus     OnePlus  ONE E1003       both
